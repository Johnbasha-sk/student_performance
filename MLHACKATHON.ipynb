# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("/content/spp.csv")
df
# Out:
#     Student_ID  Gender  Age Socioeconomic_Status  GPA  Exam_Score  Attendance  \
# 0            1  Female   20                 High  9.0          75          80
# 1            2    Male   21               Medium  8.7          72          75
# 2            3  Female   22                 High  9.5          80          90
# 3            4    Male   20                  Low  8.8          78          80
# 4            5  Female   21               Medium  8.6          74          85
# 5            6    Male   22                 High  9.2          77          88
# 6            7  Female   20                  Low  8.9          76          75
# 7            8    Male   21               Medium  8.7          73          78
# 8            9  Female   22                 High  9.3          79          87
# 9           10    Male   20                  Low  8.6          71          72
# 10          11  Female   20                 High  8.0          55          75
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  30 non-null     int64
#  1   Gender                      30 non-null     object
#  2   Age                         30 non-null     int64
#  3   Socioeconomic_Status        30 non-null     object
#  4   GPA                         30 non-null     float64
#  5   Exam_Score                  30 non-null     int64
#  6   Attendance                  30 non-null     int64
#  7   Study_Hours                 30 non-null     int64
#  8   Physical_Health             30 non-null     object
#  9   Mental_Health               30 non-null     object
#  10  Extracurricular_Activities  30 non-null     object
#  11  Teacher_Evaluation          30 non-null     object
#  12  Motivation                  30 non-null     object
# ...

# %%
df.describe()
# Out:
#        Student_ID        Age        GPA  Exam_Score  Attendance  Study_Hours  \
# count   30.000000  30.000000  30.000000   30.000000   30.000000    30.000000
# mean    15.500000  20.900000   7.776667   57.766667   74.933333     3.400000
# std      8.803408   0.844863   1.078531   14.521526    9.013145     1.792706
# min      1.000000  20.000000   6.000000   35.000000   60.000000     1.000000
# 25%      8.250000  20.000000   6.725000   45.250000   67.250000     2.000000
# 50%     15.500000  21.000000   7.950000   56.500000   75.000000     3.500000
# 75%     22.750000  22.000000   8.675000   72.750000   80.000000     5.000000
# max     30.000000  22.000000   9.500000   80.000000   90.000000     6.000000
#
#        Test_Scores
# count    30.000000
# mean   1115.666667
# std     238.424185
# min     730.000000
# 25%     855.000000
# 50%    1175.000000
# 75%    1325.000000
# max    1420.000000

# %%
df.isna().sum()
# Out:
# Student_ID                    0
# Gender                        0
# Age                           0
# Socioeconomic_Status          0
# GPA                           0
# Exam_Score                    0
# Attendance                    0
# Study_Hours                   0
# Physical_Health               0
# Mental_Health                 0
# Extracurricular_Activities    0
# Teacher_Evaluation            0
# Motivation                    0
# Technology_Usage              0
# Test_Scores                   0
# Classroom_Behavior            0
# Performance                   0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Student_ID                    False
# Gender                        False
# Age                           False
# Socioeconomic_Status          False
# GPA                           False
# Exam_Score                    False
# Attendance                    False
# Study_Hours                   False
# Physical_Health               False
# Mental_Health                 False
# Extracurricular_Activities    False
# Teacher_Evaluation            False
# Motivation                    False
# Technology_Usage              False
# Test_Scores                   False
# Classroom_Behavior            False
# Performance                   False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#     Student_ID  Gender  Age Socioeconomic_Status  GPA  Exam_Score  Attendance  \
# 0            1  Female   20                 High  9.0          75          80
# 1            2    Male   21               Medium  8.7          72          75
# 2            3  Female   22                 High  9.5          80          90
# 3            4    Male   20                  Low  8.8          78          80
# 4            5  Female   21               Medium  8.6          74          85
# 5            6    Male   22                 High  9.2          77          88
# 6            7  Female   20                  Low  8.9          76          75
# 7            8    Male   21               Medium  8.7          73          78
# 8            9  Female   22                 High  9.3          79          87
# 9           10    Male   20                  Low  8.6          71          72
# 10          11  Female   20                 High  8.0          55          75
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scales =["GPA","Exam_Score","Attendance","Study_Hours","Test_Scores"]
scaler = MinMaxScaler(feature_range=(0,1))
scaler.fit(df[scales])
df[scales]=scaler.transform(df[scales])
df.head()
# Out:
#    Student_ID  Gender  Age Socioeconomic_Status       GPA  Exam_Score  \
# 0           1  Female   20                 High  0.857143    0.888889
# 1           2    Male   21               Medium  0.771429    0.822222
# 2           3  Female   22                 High  1.000000    1.000000
# 3           4    Male   20                  Low  0.800000    0.955556
# 4           5  Female   21               Medium  0.742857    0.866667
#
#    Attendance  Study_Hours Physical_Health Mental_Health  \
# 0    0.666667          0.8       Excellent          Good
# 1    0.500000          1.0            Good     Excellent
# 2    1.000000          0.8       Excellent     Excellent
# 3    0.666667          0.6            Good          Good
# 4    0.833333          1.0       Excellent     Excellent
#
#   Extracurricular_Activities Teacher_Evaluation Motivation Technology_Usage  \
# 0                        Yes           Positive       High          Regular
# ...

# %%
X=df[["GPA","Exam_Score","Attendance","Study_Hours","Test_Scores"]].values
y=df["Performance"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %%
print (" The shape of original feature set is : ",X.shape)
print("The shape of original class labels is", y.shape)
print(" The shape of Features in training data",X_train.shape)
print("The shape of class labels in training data",y_train.shape)
print(" The shape of Features in test data",X_test.shape)
print("The shape of class labels in test data",y_test.shape)
# Out:
#  The shape of original feature set is :  (30, 5)
# The shape of original class labels is (30,)
#  The shape of Features in training data (24, 5)
# The shape of class labels in training data (24,)
#  The shape of Features in test data (6, 5)
# The shape of class labels in test data (6,)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier

# %%
#  training_features, test_features, training_target, test_target, = train_test_split(, axis=1),
#                                                   df['target'],
#                                                   test_size = .3,
#                                                   random_state=12)
# clf = RandomForestClassifier()
# trained_model = clf.fit(training_features, training_target)
# trained_model.fit(training_features, training_target)
# predictions = trained_model.predict(test_features)

# Train Accuracy: accuracy_score(training_target, trained_model.predict(training_features))
# Test Accuracy: accuracy_score(test_target, predictions)

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=10)

rf_classifier.fit(X_train, y_train)

train_predictions = rf_classifier.predict(X_train)

test_predictions = rf_classifier.predict(X_test)

train_accuracy = metrics.accuracy_score(y_train, train_predictions)

test_accuracy = metrics.accuracy_score(y_test, test_predictions)

print("Training Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)
# Out:
# Training Accuracy: 1.0
# Test Accuracy: 1.0

# %%
model_DT = DecisionTreeClassifier() # Create Decision Tree classifer object
model_DT = model_DT.fit(X_train,y_train) # Build the model using training data
y_predict_DT = model_DT.predict(X_test) # Apply the model on test data.
Actual_predicted_DT=pd.DataFrame({'predicted':y_predict_DT, 'Actual':y_test})
Actual_predicted_DT.head()
# Out:
#     predicted     Actual
# 20       Poor       Poor
# 7   Excellent  Excellent
# 5   Excellent  Excellent
# 2   Excellent  Excellent
# 3   Excellent  Excellent
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('predicted').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Actual').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...
